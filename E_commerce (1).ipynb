# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
stud=pd.read_csv("ecommerce_orders_dataset (1).csv")
stud
# Out:
#     order_id product_id  product_name        category   price  quantity  \
# 0     O00001       P242      Football          Sports   17.38         3
# 1     O00002       P617         Novel           Books   19.75         2
# 2     O00003       P877     Biography           Books  227.36         3
# 3     O00004       P489         Jeans        Clothing  478.82         3
# 4     O00005       P180       Blender  Home & Kitchen  366.22         5
# ..       ...        ...           ...             ...     ...       ...
# 995   O00996       P694      Textbook           Books  268.57         2
# 996   O00997       P671      Sneakers        Clothing    6.42         1
# 997   O00998       P247  Cookware Set  Home & Kitchen  425.13         2
# 998   O00999       P850        Laptop     Electronics   63.03         2
# 999   O01000       P130      Football          Sports  333.06         1
#
#      total_price  order_date customer_id  customer_city customer_gender  \
# ...

# %%
stud[["product_name","total_price"]].max()
# Out:
# product_name    Yoga Mat
# total_price      2475.95
# dtype: object

# %%
deliv=stud.loc[stud["delivery_status"]=="Delivered"]
deliv
# Out:
#     order_id product_id    product_name        category   price  quantity  \
# 0     O00001       P242        Football          Sports   17.38         3
# 3     O00004       P489           Jeans        Clothing  478.82         3
# 4     O00005       P180         Blender  Home & Kitchen  366.22         5
# 5     O00006       P181         T-Shirt        Clothing   27.68         2
# 6     O00007       P818          Comics           Books   85.51         3
# ..       ...        ...             ...             ...     ...       ...
# 993   O00994       P430     Moisturizer          Beauty  479.99         3
# 994   O00995       P241  Vacuum Cleaner  Home & Kitchen  214.80         4
# 995   O00996       P694        Textbook           Books  268.57         2
# 997   O00998       P247    Cookware Set  Home & Kitchen  425.13         2
# 999   O01000       P130        Football          Sports  333.06         1
#
#      total_price  order_date customer_id  customer_city customer_gender  \
# ...

# %%
countdeliv=deliv["customer_city"].value_counts()
countdeliv
# Out:
# customer_city
# Kano             159
# Port Harcourt    144
# Ibadan           139
# Abuja            138
# Lagos            132
# Name: count, dtype: int64

# %%
maxdeliv=countdeliv.idxmax()
maxdeliv
# Out:
# 'Kano'

# %%
stud
# Out:
#     order_id product_id  product_name        category   price  quantity  \
# 0     O00001       P242      Football          Sports   17.38         3
# 1     O00002       P617         Novel           Books   19.75         2
# 2     O00003       P877     Biography           Books  227.36         3
# 3     O00004       P489         Jeans        Clothing  478.82         3
# 4     O00005       P180       Blender  Home & Kitchen  366.22         5
# ..       ...        ...           ...             ...     ...       ...
# 995   O00996       P694      Textbook           Books  268.57         2
# 996   O00997       P671      Sneakers        Clothing    6.42         1
# 997   O00998       P247  Cookware Set  Home & Kitchen  425.13         2
# 998   O00999       P850        Laptop     Electronics   63.03         2
# 999   O01000       P130      Football          Sports  333.06         1
#
#      total_price  order_date customer_id  customer_city customer_gender  \
# ...

# %%
stud.groupby(["customer_id"])["total_price"].mean()
# Out:
# customer_id
# C1001     924.80
# C1014     389.73
# C1040     998.32
# C1043     165.48
# C1074     946.38
#           ...
# C9967     918.40
# C9970      66.00
# C9984     112.53
# C9992    1685.65
# C9999     954.54
# Name: total_price, Length: 948, dtype: float64

# %%
stud.dtypes
# Out:
# order_id                object
# product_id              object
# product_name            object
# category                object
# price                  float64
# quantity                 int64
# total_price            float64
# order_date              object
# customer_id             object
# customer_city           object
# customer_gender         object
# payment_method          object
# delivery_status         object
# delivery_date           object
# cancellation_reason     object
# dtype: object

# %%
stud["order_date"]=stud["order_date"].astype("datetime64[ns]")

# %%
stud.dtypes
# Out:
# order_id                       object
# product_id                     object
# product_name                   object
# category                       object
# price                         float64
# quantity                        int64
# total_price                   float64
# order_date             datetime64[ns]
# customer_id                    object
# customer_city                  object
# customer_gender                object
# payment_method                 object
# delivery_status                object
# delivery_date                  object
# cancellation_reason            object
# dtype: object

# %%
stud["month"]=stud["order_date"].dt.month_name()

# %%
stud
# Out:
#     order_id product_id  product_name        category   price  quantity  \
# 0     O00001       P242      Football          Sports   17.38         3
# 1     O00002       P617         Novel           Books   19.75         2
# 2     O00003       P877     Biography           Books  227.36         3
# 3     O00004       P489         Jeans        Clothing  478.82         3
# 4     O00005       P180       Blender  Home & Kitchen  366.22         5
# ..       ...        ...           ...             ...     ...       ...
# 995   O00996       P694      Textbook           Books  268.57         2
# 996   O00997       P671      Sneakers        Clothing    6.42         1
# 997   O00998       P247  Cookware Set  Home & Kitchen  425.13         2
# 998   O00999       P850        Laptop     Electronics   63.03         2
# 999   O01000       P130      Football          Sports  333.06         1
#
#      total_price order_date customer_id  customer_city customer_gender  \
# ...

# %%
setq=stud.groupby(["month"])["total_price"].sum(numeric_only=True).reset_index()
setq
# Out:
#         month  total_price
# 0       April     84713.63
# 1      August     40501.93
# 2    December     38667.05
# 3    February     64586.42
# 4     January     85767.59
# 5        July     55805.22
# 6        June     49108.87
# 7       March     92624.93
# 8         May     95567.36
# 9    November     48601.85
# 10    October     54044.22
# 11  September     53866.16

# %%
setq.sort_values(by="total_price",ascending=False)
# Out:
#         month  total_price
# 8         May     95567.36
# 7       March     92624.93
# 4     January     85767.59
# 0       April     84713.63
# 3    February     64586.42
# 5        July     55805.22
# 10    October     54044.22
# 11  September     53866.16
# 6        June     49108.87
# 9    November     48601.85
# 1      August     40501.93
# 2    December     38667.05

# %%
ret=stud.loc[stud["delivery_status"]=="Returned"]
ret
# Out:
#     order_id product_id product_name        category   price  quantity  \
# 7     O00008       P755     Yoga Mat          Sports   85.88         4
# 33    O00034       P859    Microwave  Home & Kitchen  320.37         3
# 43    O00044       P780    Dumbbells          Sports  279.43         2
# 52    O00053       P655     Yoga Mat          Sports   36.79         4
# 53    O00054       P120     Textbook           Books  452.90         5
# ..       ...        ...          ...             ...     ...       ...
# 947   O00948       P951     Lipstick          Beauty  205.71         5
# 948   O00949       P882     Football          Sports  305.65         2
# 953   O00954       P186      Blender  Home & Kitchen   55.16         4
# 971   O00972       P122   Smartwatch     Electronics  212.41         5
# 996   O00997       P671     Sneakers        Clothing    6.42         1
#
#      total_price order_date customer_id  customer_city customer_gender  \
# ...

# %%
val=stud["category"].value_counts()
val
# Out:
# category
# Clothing          180
# Sports            173
# Books             166
# Electronics       163
# Beauty            160
# Home & Kitchen    158
# Name: count, dtype: int64

# %%
val.idxmax()
# Out:
# 'Clothing'

# %%
stud.groupby("customer_gender")["total_price"].sum().reset_index()
# Out:
#   customer_gender  total_price
# 0          Female    402322.62
# 1            Male    361532.61

# %%
stud["product_name"].unique()
# Out:
# array(['Football', 'Novel', 'Biography', 'Jeans', 'Blender', 'T-Shirt',
#        'Comics', 'Yoga Mat', 'Wireless Earbuds', 'Microwave', 'Lipstick',
#        'Dumbbells', 'Foundation', 'Tennis Racket', 'Sneakers',
#        'Vacuum Cleaner', 'Laptop', 'Smartphone', 'Cookware Set',
#        'Perfume', 'Textbook', 'Moisturizer', 'Smartwatch', 'Jacket'],
#       dtype=object)

# %%
repeat=stud["customer_id"].value_counts()
rep=(repeat >1).sum()
rep
# Out:
# 49

# %%
cus=stud.groupby(["customer_city"])["customer_id"].count()
cus.idxmax()
# Out:
# 'Kano'

# %%
stud
# Out:
#     order_id product_id  product_name        category   price  quantity  \
# 0     O00001       P242      Football          Sports   17.38         3
# 1     O00002       P617         Novel           Books   19.75         2
# 2     O00003       P877     Biography           Books  227.36         3
# 3     O00004       P489         Jeans        Clothing  478.82         3
# 4     O00005       P180       Blender  Home & Kitchen  366.22         5
# ..       ...        ...           ...             ...     ...       ...
# 995   O00996       P694      Textbook           Books  268.57         2
# 996   O00997       P671      Sneakers        Clothing    6.42         1
# 997   O00998       P247  Cookware Set  Home & Kitchen  425.13         2
# 998   O00999       P850        Laptop     Electronics   63.03         2
# 999   O01000       P130      Football          Sports  333.06         1
#
#      total_price order_date customer_id  customer_city customer_gender  \
# ...

# %%
stud["order_date"]=pd.to_datetime(stud["order_date"])

# %%
stud["delivery_date"]=stud["delivery_date"].astype("datetime64[ns]")

# %%
stud["delivery_time"]=(stud["delivery_date"]-stud["order_date"]).dt.days

# %%
stud
# Out:
#     order_id product_id  product_name        category   price  quantity  \
# 0     O00001       P242      Football          Sports   17.38         3
# 1     O00002       P617         Novel           Books   19.75         2
# 2     O00003       P877     Biography           Books  227.36         3
# 3     O00004       P489         Jeans        Clothing  478.82         3
# 4     O00005       P180       Blender  Home & Kitchen  366.22         5
# ..       ...        ...           ...             ...     ...       ...
# 995   O00996       P694      Textbook           Books  268.57         2
# 996   O00997       P671      Sneakers        Clothing    6.42         1
# 997   O00998       P247  Cookware Set  Home & Kitchen  425.13         2
# 998   O00999       P850        Laptop     Electronics   63.03         2
# 999   O01000       P130      Football          Sports  333.06         1
#
#      total_price order_date customer_id  customer_city customer_gender  \
# ...

# %%
average=stud.groupby(["customer_city"])["delivery_time"].mean().reset_index()
average
# Out:
#    customer_city  delivery_time
# 0          Abuja       5.637681
# 1         Ibadan       5.920863
# 2           Kano       5.591195
# 3          Lagos       5.962121
# 4  Port Harcourt       6.090278

# %%
value=stud.groupby(["payment_method"])["delivery_status"].value_counts().reset_index()
value
# Out:
#       payment_method delivery_status  count
# 0      Bank Transfer       Delivered    149
# 1      Bank Transfer       Cancelled     33
# 2      Bank Transfer        Returned     22
# 3      Bank Transfer         Pending     10
# 4   Cash on Delivery       Delivered    135
# 5   Cash on Delivery       Cancelled     29
# 6   Cash on Delivery        Returned     15
# 7   Cash on Delivery         Pending      8
# 8        Credit Card       Delivered    142
# 9        Credit Card        Returned     24
# 10       Credit Card       Cancelled     20
# 11       Credit Card         Pending      7
# 12        Debit Card       Delivered    147
# 13        Debit Card        Returned     29
# 14        Debit Card       Cancelled     25
# 15        Debit Card         Pending      7
# 16            PayPal       Delivered    139
# 17            PayPal       Cancelled     28
# 18            PayPal        Returned     17
# 19            PayPal         Pending     14

# %%
value.groupby(["payment_method"])["delivery_status"].max().reset_index()
# Out:
#      payment_method delivery_status
# 0     Bank Transfer        Returned
# 1  Cash on Delivery        Returned
# 2       Credit Card        Returned
# 3        Debit Card        Returned
# 4            PayPal        Returned

# %%
most=value.groupby(["payment_method"])["delivery_status"].apply(lambda x:x.value_counts().idxmax()).reset_index(name="most_common")
most
# Out:
#      payment_method most_common
# 0     Bank Transfer   Delivered
# 1  Cash on Delivery   Delivered
# 2       Credit Card   Delivered
# 3        Debit Card   Delivered
# 4            PayPal   Delivered

# %%
stud["day_of_week"]=stud["order_date"].dt.day_name()

# %%
stud["weekend"]=stud["day_of_week"].isin(["Satuday","Sunday"])

# %%
weekend=stud.loc[stud["weekend"]==True]
weekend
# Out:
#     order_id product_id    product_name        category   price  quantity  \
# 1     O00002       P617           Novel           Books   19.75         2
# 5     O00006       P181         T-Shirt        Clothing   27.68         2
# 14    O00015       P600       Microwave  Home & Kitchen  271.99         5
# 17    O00018       P353          Comics           Books  221.86         5
# 29    O00030       P235        Lipstick          Beauty   41.26         2
# ..       ...        ...             ...             ...     ...       ...
# 980   O00981       P259        Sneakers        Clothing  138.05         5
# 990   O00991       P538         Blender  Home & Kitchen  448.32         5
# 994   O00995       P241  Vacuum Cleaner  Home & Kitchen  214.80         4
# 996   O00997       P671        Sneakers        Clothing    6.42         1
# 997   O00998       P247    Cookware Set  Home & Kitchen  425.13         2
#
#      total_price order_date customer_id  customer_city customer_gender  \
# ...

# %%
weekday=stud.loc[stud["weekend"]==False]
weekday
# Out:
#     order_id product_id product_name        category   price  quantity  \
# 0     O00001       P242     Football          Sports   17.38         3
# 2     O00003       P877    Biography           Books  227.36         3
# 3     O00004       P489        Jeans        Clothing  478.82         3
# 4     O00005       P180      Blender  Home & Kitchen  366.22         5
# 6     O00007       P818       Comics           Books   85.51         3
# ..       ...        ...          ...             ...     ...       ...
# 992   O00993       P499       Laptop     Electronics  390.00         2
# 993   O00994       P430  Moisturizer          Beauty  479.99         3
# 995   O00996       P694     Textbook           Books  268.57         2
# 998   O00999       P850       Laptop     Electronics   63.03         2
# 999   O01000       P130     Football          Sports  333.06         1
#
#      total_price order_date customer_id  customer_city customer_gender  \
# ...

# %%
cancel_weekend=(weekend["delivery_status"]=="Cancelled").mean()
cancel_weekend*100
# Out:
# 14.37908496732026

# %%
cancel_weekday=(weekday["delivery_status"]=="Cancelled").mean()
cancel_weekday*100
# Out:
# 13.34120425029516

# %%
delay_weekend=(weekend["delivery_status"]=="Delayed").mean()
delay_weekend*100
# Out:
# 0.0

# %%
delay_weekday=(weekday["delivery_status"]=="Delayed").mean()
delay_weekday*100
# Out:
# 0.0

# %%
stud
# Out:
#     order_id product_id  product_name        category   price  quantity  \
# 0     O00001       P242      Football          Sports   17.38         3
# 1     O00002       P617         Novel           Books   19.75         2
# 2     O00003       P877     Biography           Books  227.36         3
# 3     O00004       P489         Jeans        Clothing  478.82         3
# 4     O00005       P180       Blender  Home & Kitchen  366.22         5
# ..       ...        ...           ...             ...     ...       ...
# 995   O00996       P694      Textbook           Books  268.57         2
# 996   O00997       P671      Sneakers        Clothing    6.42         1
# 997   O00998       P247  Cookware Set  Home & Kitchen  425.13         2
# 998   O00999       P850        Laptop     Electronics   63.03         2
# 999   O01000       P130      Football          Sports  333.06         1
#
#      total_price order_date customer_id  customer_city customer_gender  \
# ...

# %%
mos=stud.groupby(["delivery_status"])["quantity"].sum().reset_index(name="most")
mos
mos.sort_values(by="most",ascending=False)
# Out:
#   delivery_status  most
# 1       Delivered  2149
# 0       Cancelled   397
# 3        Returned   371
# 2         Pending   133

# %%
stud
# Out:
#     order_id product_id  product_name        category   price  quantity  \
# 0     O00001       P242      Football          Sports   17.38         3
# 1     O00002       P617         Novel           Books   19.75         2
# 2     O00003       P877     Biography           Books  227.36         3
# 3     O00004       P489         Jeans        Clothing  478.82         3
# 4     O00005       P180       Blender  Home & Kitchen  366.22         5
# ..       ...        ...           ...             ...     ...       ...
# 995   O00996       P694      Textbook           Books  268.57         2
# 996   O00997       P671      Sneakers        Clothing    6.42         1
# 997   O00998       P247  Cookware Set  Home & Kitchen  425.13         2
# 998   O00999       P850        Laptop     Electronics   63.03         2
# 999   O01000       P130      Football          Sports  333.06         1
#
#      total_price order_date customer_id  customer_city customer_gender  \
# ...

# %%
cancel=stud.loc[stud["delivery_status"]=="Cancelled"]
cancel
cancel_1=cancel["product_name"].value_counts()
cancel_1.idxmax()
# Out:
# 'Novel'

# %%
stud["product_name"].value_counts().idxmax()
# Out:
# 'Dumbbells'

# %%
avg_max=stud.groupby(["product_name"])["price"].mean().reset_index(name="average_price")
avg_max.max()
# Out:
# product_name       Yoga Mat
# average_price    284.781639
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='whitegrid')

# %% [markdown]
# ### Order by Delivery Status

# %%
plt.figure(figsize=(7, 4))
sns.countplot(data=stud, x='delivery_status', palette='Set2')
plt.title('Count of Orders by Delivery Status')
plt.xlabel('Delivery Status')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Top cities by number of Deliveries

# %%
top_cities = stud[stud['delivery_status'] == 'Delivered']['customer_city'].value_counts().head(10)
plt.figure(figsize=(8, 4))
sns.barplot(x=top_cities.values, y=top_cities.index, palette='Blues_d')
plt.title('Top 10 Cities by Number of Deliveries')
plt.xlabel('Number of Deliveries')
plt.ylabel('City')
plt.show()

# %% [markdown]
# ### Distribution of Total Price

# %%
plt.figure(figsize=(10, 4))
sns.histplot(stud['total_price'], bins=30, kde=True, color='purple')
plt.title('Distribution of Total Price')
plt.xlabel('Total Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Total price by Payment type

# %%
plt.figure(figsize=(10, 4))
sns.boxplot(data=stud, x='payment_method', y='total_price', palette='Set3')
plt.title('Total Price by Payment Type')
plt.xlabel('Payment Type')
plt.ylabel('Total Price')
plt.xticks(rotation=45)
plt.show()
